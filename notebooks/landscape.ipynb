# %% [markdown]
# # The Space of Spaces

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot simply exponential function
x = np.arange(-3.0, 3.0, 0.1)
y = np.exp(x)
fs = 10
fig, ax = plt.subplots(figsize=(fs*2, fs))
ax.plot(x, y)
